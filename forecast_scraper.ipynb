# %% [markdown]
# EXAMPLE: https://mesonet.agron.iastate.edu/wx/afos/p.php?pil=FWFBUF&e=201512280953

# %%
from bs4 import BeautifulSoup
from itertools import cycle
import pandas as pd
import re
import requests

# %%
forecast = 'https://mesonet.agron.iastate.edu/wx/afos/p.php?pil=FWFBUF&e=201512280953'
#reading file contents
source=requests.get(forecast).text
soup=BeautifulSoup(source,'lxml')

text = soup.find('pre')

text = str(text)

text = text.strip()

paragraphs = text.split('\n\n')

for paragraph in paragraphs:
    print(paragraph.lower())
    print('***')
# Out:
# <pre>
# 570
# fnus51 kbuf 280953
# fwfbuf
# ***
# fire weather planning forecast for western new york
# national weather service buffalo ny
# 453 am est mon dec 28 2015
# ***
# .discussion...
# ***
# low pressure will lift into the great lakes and bring a wintry mix
# to the region tonight. gusty southerly winds will warm temperatures
# late tonight and change precipitation to rain on tuesday. following
# this system...colder air will return later in the week along with
# increasing chances of snow showers and some lake effect snow.
# ***
# nyz001-002-010-011-282115-
# niagara-orleans-northern erie-genesee-
# 453 am est mon dec 28 2015
# ***
#                                 today      tonight          tue
# cloud cover                     mcldy       cloudy       cloudy
# precip chc (%)                      0          100           70
# precip type                      none   sleet/rain      showers
# min/max temp                       31           26           44
# am wind (mph)                   ne 13                     se 16
# pm wind (mph)                    e 16         e 17        sw 12
# precip amount                    0.00         0.68         0.10
# precip duration                                 12            6
# precip begin                                  6 pm   continuing
# precip end                              continuing   continuing
# max/min humidity (%)               55           91           79
# haines index                        4            2            3
# lal                                 1            1            1
# mixing hgt (ft-agl)              3890          470         3960
# transport wind (kt)             ne 16        se 19        sw 18
# vent rate (kt-ft)               62240         8930        71280
# dispersion index                   62            9           71
# remarks...none.
# ***
# $$
# ***
# nyz012-019&gt;021-085-282115-
# wyoming-chautauqua-cattaraugus-allegany-southern erie-
# 453 am est mon dec 28 2015
# ***
#                                 today      tonight          tue
# cloud cover                    cloudy       cloudy        mcldy
# precip chc (%)                     90          100           50
# precip type                  frz rain     frz rain     frz rain
# min/max temp                       30           26           45
# am wind (mph)                   ne 11                      s 21
# pm wind (mph)                    e 13        se 17        sw 13
# precip amount                    0.08         0.44         0.08
# precip duration                     2           11            4
# precip begin                     3 pm   continuing   continuing
# precip end                 continuing   continuing   continuing
# max/min humidity (%)               54           92           78
# haines index                        4            2            3
# lal                                 1            1            1
# mixing hgt (ft-agl)              3430          620         4450
# transport wind (kt)             ne 16         s 32        sw 27
# vent rate (kt-ft)               54880        19840       120150
# dispersion index                   55           20          120
# remarks...none.
# ***
# $$
# ***
# nyz003&gt;005-013-014-282115-
# monroe-wayne-northern cayuga-livingston-ontario-
# 453 am est mon dec 28 2015
# ***
#                                 today      tonight          tue
# cloud cover                     mcldy       cloudy       cloudy
# precip chc (%)                     30          100           70
# precip type                  frz rain     frz rain     frz rain
# min/max temp                       31           27           45
# am wind (mph)                   ne 13                     se 18
# pm wind (mph)                    e 12         e 14         s 11
# precip amount                    0.01         0.51         0.10
# precip duration                     1           11            8
# precip begin                     6 am         7 pm   continuing
# precip end                       9 am   continuing   continuing
# max/min humidity (%)               47           86           77
# haines index                        4            3            3
# lal                                 1            1            1
# mixing hgt (ft-agl)              4220         1040         3490
# transport wind (kt)              n 18        se 28         w 19
# vent rate (kt-ft)               75960        29120        66310
# dispersion index                   76           29           66
# remarks...none.
# ***
# $$
# ***
# nyz006&gt;008-282115-
# oswego-jefferson-lewis-
# 453 am est mon dec 28 2015
# ***
#                                 today      tonight          tue
# cloud cover                     pcldy       cloudy       cloudy
# precip chc (%)                      0          100          100
# precip type                      none   snow/fz ra    snow/rain
# min/max temp                       29           20           39
# am wind (mph)                   ne 11                     se 16
# pm wind (mph)                   ne  9         e 10        se 10
# precip amount                    0.00         0.51         0.38
# precip duration                                  9           12
# precip begin                                  8 pm   continuing
# precip end                              continuing   continuing
# max/min humidity (%)               42           84           73
# haines index                        4            3            2
# lal                                 1            1            1
# mixing hgt (ft-agl)              4100         1170         2820
# transport wind (kt)              n 18        se 17        se 27
# vent rate (kt-ft)               73800        19890        76140
# dispersion index                   74           20           76
# remarks...none.
# ***
# $$
# ***
# .extended forecast...
# ***
# .tuesday night...mostly cloudy with a chance of rain showers and
# freezing drizzle. lows in the mid 30s.
# .wednesday...mostly cloudy with a chance of rain showers and
# freezing drizzle. highs in the lower 40s.
# .thursday...mostly cloudy with a chance of rain and snow showers.
# lows in the lower 30s. highs in the upper 30s.
# .friday...mostly cloudy with a chance of snow and rain showers.
# lows in the upper 20s. highs in the mid 30s.
# .saturday...mostly cloudy with a chance of snow showers. lows in
# the mid 20s. highs in the lower 30s.
# .sunday...mostly cloudy with a chance of snow showers. lows in
# the mid 20s. highs in the lower 30s.
# ***
# wind tuesday night...south around 10 mph.
# wind wednesday...southwest around 5 mph.
# wind thursday...west around 10 mph.
# wind friday...west 10 to 15 mph.
# ***
# .outlook 8 to 14 days...
# temperatures above normal.  precipitation below normal.
# ***
# $$
# </pre>
# ***

# %%
forecast = 'https://mesonet.agron.iastate.edu/wx/afos/p.php?pil=FWFBUF&e=201512280953'
#reading file contents
source=requests.get(forecast).text
soup=BeautifulSoup(source,'lxml')

text = soup.find('pre')
text = str(text)
text = text.strip()
paragraphs = text.split('\n\n')

running = True
licycle = cycle(paragraphs)
# Prime the pump



for paragraph in paragraphs:
    nextelem = next(licycle)
    while running:
        thiselem, nextelem = nextelem, next(licycle)
        #print(paragraph.lower())
        #print('***')
        if thiselem.startswith('NYZ001'):
            print(thiselem.lower())
            print('\n')
            print(nextelem.lower())
        elif thiselem.startswith('.DISCUSSION'):
            print(nextelem.lower())
            print('\n')
        elif '</pre>' in thiselem:
            running = False
# Out:
# low pressure will lift into the great lakes and bring a wintry mix
# to the region tonight. gusty southerly winds will warm temperatures
# late tonight and change precipitation to rain on tuesday. following
# this system...colder air will return later in the week along with
# increasing chances of snow showers and some lake effect snow.
#
#
# nyz001-002-010-011-282115-
# niagara-orleans-northern erie-genesee-
# 453 am est mon dec 28 2015
#
#
#                                 today      tonight          tue
# cloud cover                     mcldy       cloudy       cloudy
# precip chc (%)                      0          100           70
# precip type                      none   sleet/rain      showers
# min/max temp                       31           26           44
# am wind (mph)                   ne 13                     se 16
# pm wind (mph)                    e 16         e 17        sw 12
# precip amount                    0.00         0.68         0.10
# precip duration                                 12            6
# precip begin                                  6 pm   continuing
# precip end                              continuing   continuing
# max/min humidity (%)               55           91           79
# haines index                        4            2            3
# lal                                 1            1            1
# mixing hgt (ft-agl)              3890          470         3960
# transport wind (kt)             ne 16        se 19        sw 18
# vent rate (kt-ft)               62240         8930        71280
# dispersion index                   62            9           71
# remarks...none.

# %%
forecast = 'https://mesonet.agron.iastate.edu/wx/afos/p.php?pil=FWFBUF&e=201512280953'
#reading file contents
source=requests.get(forecast).text
soup=BeautifulSoup(source,'lxml')

text = soup.find('pre')
text = str(text)
text = text.strip()
paragraphs = text.split('\n\n')

running = True
licycle = cycle(paragraphs)
# Prime the pump



for paragraph in paragraphs:
    nextelem = next(licycle)
    while running:
        thiselem, nextelem = nextelem, next(licycle)
        #print(paragraph.lower())
        #print('***')
        if thiselem.startswith('NYZ001'):
            date = thiselem.lower()
            date = re.sub('\n', '', date)
            date = re.sub('(^(.*?)est)', '',date)
            print(date)
            print('\n')
            print(nextelem.lower())
        elif thiselem.startswith('.DISCUSSION'):
            print(nextelem.lower())
            print('\n')
        elif '</pre>' in thiselem:
            running = False
# Out:
# low pressure will lift into the great lakes and bring a wintry mix
# to the region tonight. gusty southerly winds will warm temperatures
# late tonight and change precipitation to rain on tuesday. following
# this system...colder air will return later in the week along with
# increasing chances of snow showers and some lake effect snow.
#
#
#  mon dec 28 2015
#
#
#                                 today      tonight          tue
# cloud cover                     mcldy       cloudy       cloudy
# precip chc (%)                      0          100           70
# precip type                      none   sleet/rain      showers
# min/max temp                       31           26           44
# am wind (mph)                   ne 13                     se 16
# pm wind (mph)                    e 16         e 17        sw 12
# precip amount                    0.00         0.68         0.10
# precip duration                                 12            6
# precip begin                                  6 pm   continuing
# precip end                              continuing   continuing
# max/min humidity (%)               55           91           79
# haines index                        4            2            3
# lal                                 1            1            1
# mixing hgt (ft-agl)              3890          470         3960
# transport wind (kt)             ne 16        se 19        sw 18
# vent rate (kt-ft)               62240         8930        71280
# dispersion index                   62            9           71
# remarks...none.
